# %% [markdown]
# <a href="https://colab.research.google.com/github/Sylvester107/Few-Shot-Learning-for-Effective-Categorization-and-Recommendation-of-Low-Frequency-Products/blob/main/paper_1304_first_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,f1_score
#!pip install transformers
#!pip install sentence_transformers
#import torch
#from transformers import AutoTokenizer, AutoModel
import pickle

# %%
data = pd.read_csv("/content/drive/MyDrive/Few shot learning for categorization and recommendation/training_data_uk_only_labeled.csv")
data.head()
# Out:
#       product  label                                              title  \
# 0  B0BFDL54Y7      1  Wokii Vegetable Chopper Vegetable Slicer 14 in...
# 1  B0BFDR9X13      0  Wokii Vegetable Chopper Vegetable Slicer 14 in...
# 2  B07J4WF8VH      1  Vinsani® Kitchen Vegetable Cutter Onion Garlic...
# 3  B07Y21LDJX      0  ADOV Vegetable Chopper, 14 in 1 Multi-Function...
# 4  B07Y227WNJ      0  ADOV Vegetable Chopper, 14 in 1 Multi-Function...
#
#    price    brand       color                              size model  \
# 0  15.99    Wokii        Blue  33x12x12cm/12.87*4.68*4.68inches   NaN
# 1  14.99    Wokii  Grey+green  33x12x12cm/12.87*4.68*4.68inches   NaN
# 2  16.99  Vinsani       White                               NaN   NaN
# 3  21.99     ADOV        Blue                               NaN   NaN
# 4  21.99     ADOV        Grey                               NaN   NaN
#
#                                material author  \
# 0                  Acrylonitrile Butadi    NaN
# 1                  Acrylonitrile Butadi    NaN
# 2                       Stainless Steel    NaN
# 3  Premium ABS Plastic, Stainless Steel    NaN
# 4  Premium ABS Plastic, Stainless Steel    NaN
#
#                                                 desc
# 0  【Easy To Clean】The blade is easy to remove, ea...
# 1  【Easy To Clean】The blade is easy to remove, ea...
# 2  CAUTION: If the vegetable or fruit has a tough...
# 3  【EASY CLEANING】 ADOV vegetable slicer can be c...
# 4  【EASY CLEANING】 ADOV vegetable slicer can be c...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494409 entries, 0 to 494408
# Data columns (total 11 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   product   494409 non-null  object
#  1   label     494409 non-null  int64
#  2   title     494409 non-null  object
#  3   price     494409 non-null  float64
#  4   brand     490162 non-null  object
#  5   color     374047 non-null  object
#  6   size      298149 non-null  object
#  7   model     240793 non-null  object
#  8   material  295942 non-null  object
#  9   author    18582 non-null   object
#  10  desc      455736 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 41.5+ MB

# %%
data.isnull().sum()
# Out:
# product          0
# label            0
# title            0
# price            0
# brand         4247
# color       120362
# size        196260
# model       253616
# material    198467
# author      475827
# desc         38673
# dtype: int64

# %% [markdown]
# store the Text part of the data for and generate their embeddings
# 0. Replace NAN with defaults#had tomeback to make this change as float was not subsriptable and error during embedding generation
# 1. the author column has too many NAN values so it won't be included
# 2. Product is unique so it won't be included

# %%
#for each column if the value at row i is nan set to column name
for col in data.columns:
  data.fillna(col, inplace=True)

# %%
thousand_samples = data.sample(n=3000, random_state=42)

# %%
training_data_text = thousand_samples[['title','brand', 'color', 'size', 'desc', 'material', 'model']]
training_data_text.head()
# Out:
#                                                     title  \
# 448226  WERNNSAI Flamingo Party Invitations with Envel...
# 350110  BENECREAT 30 Packs Brown Kraft Paper Boxes Sma...
# 420407  Border Terrier Calendar 2023 | Square Dog Bree...
# 260449  Unisex 4 LED Lighted Beanie Cap, USB Rechargea...
# 396101    REDKEN Colour Extend Magnetics Shampoo, 1000 ml
#
#                           brand          color             size  \
# 448226                 WERNNSAI  Flamingo Pink          product
# 350110                BENECREAT          Brown        8.5x6x3cm
# 420407  Avonside Publishing Ltd        product          product
# 260449                   WEITOO           Blue         One size
# 396101                   REDKEN        product  1 l (Pack of 1)
#
#                                                      desc material  \
# 448226  🍍【DETAILS】 - We provide adhesive tape on the b...    Paper
# 350110  [Good Quality]: Made of sturdy paper, environm...  Plastic
# 420407                                            product  product
# 260449  Best Christmas Gift-Bought for My Husband Our ...  Acrylic
# 396101                           Hair type: Color Treated  product
#
#                                 model
# 448226  WR-Flamingo Invitation-001-UK
# 350110                        product
# 420407                        product
# 260449                        product
# 396101                  0884486136336

# %%
training_data_text.isnull().sum()
# Out:
# title       0
# brand       0
# color       0
# size        0
# desc        0
# material    0
# model       0
# dtype: int64

# %% [markdown]
# We will create the first supervised model not few-shot based
#
# 1. Generate model embeddings using transformer
# 2. Train classifier(XGboost, GRADBoost etc)

# %% [markdown]
# I am reducing the training data once again to test method feasibility, as the ram provided by colab is too small

# %%
#training_data_text = text_data.sample(n=1000, random_state=42)

# %%
#import sentence_transformers

from sentence_transformers import SentenceTransformer
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# for each of the column in data_text generate an embedding add to a dictionary
text_embeddings = {}

for col in training_data_text.columns:
  text_embeddings[col] = model.encode(training_data_text[col].values,show_progress_bar =True)
  text_embeddings[col] = np.array(text_embeddings[col])
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/94 [00:00<?, ?it/s]
# Batches:   0%|          | 0/94 [00:00<?, ?it/s]
# Batches:   0%|          | 0/94 [00:00<?, ?it/s]
# Batches:   0%|          | 0/94 [00:00<?, ?it/s]
# Batches:   0%|          | 0/94 [00:00<?, ?it/s]
# Batches:   0%|          | 0/94 [00:00<?, ?it/s]
# Batches:   0%|          | 0/94 [00:00<?, ?it/s]

# %% [markdown]
# 1. convert text embeddings to a dataframe
# 2. add price and label to this dataframe
# 3. then split into train and test
# 4. after that train a classifier
#
# NB: we are not performing a fine-tuning because we don't have a pre-trained  model ready

# %%
#convert text embedding to a pickle file for retrieval in case of crash
#with open('text_embeddings.pkl', 'wb') as f:
 #   pickle.dump(text_embeddings, f)

# %%
text_embeddings['brand'][0]
# Out:
# array([-9.47333649e-02,  1.61780007e-02, -1.23976804e-01,  6.08473308e-02,
#        -2.63606906e-02, -1.56721435e-02,  8.96072090e-02,  2.04411279e-02,
#         5.70392236e-02, -2.75329705e-02,  1.43329119e-02, -7.73995072e-02,
#        -7.31678829e-02,  6.64781779e-02, -2.56281383e-02, -4.26454470e-02,
#         2.25475966e-03,  2.90483814e-02, -4.68797423e-02, -7.94182196e-02,
#        -7.18546659e-02,  6.05011024e-02,  3.07192802e-02,  1.99930314e-02,
#         4.07910421e-02, -1.62909813e-02, -1.05812000e-02,  2.07616948e-02,
#         6.65747887e-03, -6.72302693e-02,  5.77732772e-02, -2.23878212e-02,
#         3.11963297e-02, -1.99739411e-02, -2.58087292e-02,  4.26683314e-02,
#        -3.89305018e-02,  1.42248617e-02,  2.36931257e-02, -2.93980842e-03,
#        -4.25087176e-02, -3.41552380e-03,  1.77468397e-02,  1.32267922e-02,
#        -2.06489824e-02,  2.95582879e-02, -1.26432791e-01,  7.84012899e-02,
#         6.83402941e-02,  7.27718771e-02, -3.56775559e-02,  4.27131951e-02,
#         1.81364175e-02, -2.31962614e-02,  1.44776152e-02,  1.14344480e-03,
#        -2.52639279e-02, -5.33284433e-03,  3.02393846e-02,  1.77560840e-02,
#        -5.07239401e-02, -8.08003768e-02,  1.81970000e-02, -6.37939423e-02,
#        -7.55369142e-02,  9.32248756e-02,  3.54903825e-02,  8.78519379e-03,
#        -4.23642360e-02, -3.34513560e-02,  8.68343376e-03,  1.52500542e-02,
#         2.85194302e-03, -4.63419035e-02, -7.45690241e-02, -7.89228901e-02,
#         6.82466552e-02,  1.34932995e-02,  1.10991471e-01,  4.77445051e-02,
#         3.44139636e-02,  2.89324690e-02, -3.83292474e-02,  3.12397238e-02,
#         3.65469009e-02,  1.77456439e-02, -3.05686500e-02,  3.58697190e-03],
#       dtype=float32)

# %%
# append price and labels in the text_data to text_embeddings
text_embeddings['price'] = thousand_samples['price'].values
#text_embeddings['label'] = data['label'].values #not necessary
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-03a8cf76c926> in <cell line: 0>()
#       1 # append price and labels in the text_data to text_embeddings
# ----> 2 text_embeddings['price'] = thousand_samples['price'].values
#       3 #text_embeddings['label'] = data['label'].values #not necessary
#
# NameError: name 'text_embeddings' is not defined

# %%
#save text embeddings to pickle to drive
with open('/content/drive/MyDrive/Few shot learning for categorization and recommendation/text_embeddings.pkl', 'wb') as f:
    pickle.dump(text_embeddings, f)

# %% [markdown]
# Part 2, change runtime to cpu and run a few lines of code above and continue from here, don't run transformer part

# %%
#load pickle file
with open('/content/drive/MyDrive/Few shot learning for categorization and recommendation/text_embeddings.pkl', 'rb') as f:
    text_embeddings = pickle.load(f)

# %%
embedding_list = list(text_embeddings.values())[:-1]
embedding_list.append(text_embeddings['price'].reshape(-1, 1))  # Reshape price to 2D array
feature_matrix = np.concatenate(embedding_list, axis=1)  # Concatenate along columns (axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(feature_matrix, thousand_samples['label'].values, test_size=0.2, random_state=42)

# %% [markdown]
# Next we train all 3 boosting models and evaluate them

# %%
Gradboost = GradientBoostingClassifier(n_estimators=100,random_state=0)
Gradboost.fit(X_train, y_train)
Gradboost.score(X_test, y_test)
# Out:
# 0.795

# %%
Xgboost = xgb.XGBClassifier(objective="binary:logistic", random_state=42)
Xgboost.fit(X_train, y_train)
Xgboost.score(X_test, y_test)
# Out:
# 0.805

# %%
ada = AdaBoostClassifier(n_estimators=100, random_state=0)
ada.fit(X_train, y_train)
ada.score(X_test, y_test)
# Out:
# 0.7783333333333333

# %%
# try svc
from sklearn.svm import SVC
svc = SVC(kernel='rbf')
svc.fit(X_train, y_train)
svc.score(X_test, y_test)
# Out:
# 0.8066666666666666

# %% [markdown]
# SVC learn at a faster rate with in less time

# %% [markdown]
# 1. Use gridsearch to improve performance of both SVC and XGB
# 2. for each of these models pass all the train data into the model, no spliting into test/train then make predictions take the prediction probabilities and append to the training data again for few-shot ranking.

# %%
# find best params for svc using gridsearch
from sklearn.model_selection import GridSearchCV

param_grid = {'C': [0.1, 1, 10, 100], 'gamma': [1, 0.1, 0.01, 0.001], 'kernel': ['rbf']}

grid= GridSearchCV(SVC(),param_grid,refit=False,verbose=2)
grid.fit(X_train,y_train)

best_params = grid.best_params_
print(best_params)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   9.6s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   9.5s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=  10.1s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=  11.7s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=  10.1s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   9.7s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=  10.0s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=  10.1s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   9.3s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=  10.2s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   8.3s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   7.9s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   8.4s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   7.9s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   7.9s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   8.6s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=  14.6s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   6.7s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   7.3s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   6.4s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=  10.1s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   9.9s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   9.5s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=  10.2s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=  10.1s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   9.1s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   9.5s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=  10.4s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   9.5s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   9.3s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   8.0s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   7.6s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   8.1s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   7.8s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   8.0s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   7.7s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   7.2s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   8.0s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   7.1s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   7.7s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=  10.7s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   9.9s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=  10.5s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=  10.6s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=  10.8s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   9.7s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=  10.3s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=  10.1s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=  10.0s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   9.8s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   7.9s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   7.4s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   7.8s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   7.8s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   7.7s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   7.6s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   7.0s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   7.8s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   7.1s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   7.8s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=  10.6s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=  10.3s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=  10.7s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=  10.7s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=  10.6s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=  10.0s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=  10.6s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=  10.7s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=  10.7s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=  10.1s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   9.4s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   9.8s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   9.4s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   9.5s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   9.7s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   7.1s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   7.7s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   7.1s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   7.4s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   7.4s
# {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_available_if.py in _check(self, obj, owner)
#      31         try:
# ---> 32             check_result = self.check(obj)
#      33         except Exception as e:
#
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py in _check_proba(self)
#     830         if not self.probability:
# --> 831             raise AttributeError(
#     832                 "predict_proba is not available when probability=False"
#
# AttributeError: predict_proba is not available when probability=False
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-bd59b52af56e> in <cell line: 0>()
#      15
#      16 #generate and store the ouput probabilites of each sample in a list
# ---> 17 output_probabilities = svc.predict_proba(feature_matrix)
#      18 print(output_probabilities)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_available_if.py in __get__(self, obj, owner)
#      41             # delegate only on instances, not the classes.
#      42             # this is to allow access to the docstrings.
# ---> 43             self._check(obj, owner=owner)
#      44             out = MethodType(self.fn, obj)
#      45
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_available_if.py in _check(self, obj, owner)
#      32             check_result = self.check(obj)
#      33         except Exception as e:
# ---> 34             raise AttributeError(attr_err_msg) from e
#      35
#      36         if not check_result:
#
# AttributeError: This 'SVC' has no attribute 'predict_proba'

# %%
#{'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
#retrain svc with best params, pass the whole training data i.e feature matrix
svc = SVC(kernel='rbf', C=0.1, gamma=1,probability=True)
svc.fit(feature_matrix, thousand_samples['label'].values)

#generate and store the ouput probabilites of each sample in a list
output_probabilities = svc.predict_proba(feature_matrix)
print(output_probabilities)
# Out:
# [[0.09293491 0.90706509]
#  [0.0933766  0.9066234 ]
#  [0.09289707 0.90710293]
#  ...
#  [0.09362302 0.90637698]
#  [0.09390178 0.90609822]
#  [0.09188672 0.90811328]]

# %%
# attach output probability of each sample as a new column in feature matrix
for i in range(output_probabilities.shape[1]):
    feature_matrix = np.hstack((feature_matrix, output_probabilities[:, i].reshape(-1, 1)))

# %%
feature_matrix.shape
# Out:
# (3000, 2691)

# %% [markdown]
# The last value in our feature matrix is the probability that this product is a low frequency product, learned using SVC

# %%
feature_matrix[1][-1]
# Out:
# 0.9066234004616708

# %%
#save feature matrix to drive using pickle
with open('/content/drive/MyDrive/Few shot learning for categorization and recommendation/feature_matrix.pkl', 'wb') as f:
    pickle.dump(feature_matrix, f)

# %% [markdown]
# XGboost seems to be performing very well, focus on optimizing it
#
# techniques:
# - Gridsearch for hyperparameter tuning
# - add 1000 more data points

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators': [50, 100, 150], 'grow_policy' : ['depthwise','lossguide'], 'learning_rate': [0.01, 0.1, 1], }

# %% [markdown]
# MRR@100

# %%
"""import numpy as np
from scipy.stats import rankdata

def mean_reciprocal_rank(y_true, y_pred, k=100):
    mrrs = []
    for true_labels, pred_scores in zip(y_true, y_pred):
        ranks = rankdata(-pred_scores, method='ordinal')
        true_ranks = ranks[np.argmax(true_labels)]
        if true_ranks <= k:
            mrrs.append(1.0 / true_ranks)
        else:
            mrrs.append(0)
    return np.mean(mrrs) """
